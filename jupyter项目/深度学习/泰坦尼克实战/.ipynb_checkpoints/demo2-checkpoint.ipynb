# %%
import pandas as pd
import numpy as np 
import tensorflow as tf
from tensorflow import keras
import time
import warnings
warnings.filterwarnings('ignore')

# %%
train_file='./train.csv'
eval_file='./eval.csv'

# %%
train_df=pd.read_csv(train_file)
eval_df=pd.read_csv(eval_file)

# %%
y_train=train_df.pop('survived')
y_eval=eval_df.pop('survived')

# %%
categorical_columns=['sex','n_siblings_spouses','parch','class',
                        'deck','embark_town','alone']
numeric_columns=['age','fare']
feature_columns=[]

# %%
for categorical_column in categorical_columns:
    vocab=train_df[categorical_column].unique()
    vocab_list=tf.feature_column.categorical_column_with_vocabulary_list(
        categorical_column,vocab)
    vocab_list=tf.feature_column.indicator_column(vocab_list)
    feature_columns.append(vocab_list)

# %%
for categorical_column in numeric_columns:
    num_list=tf.feature_column.numeric_column(
        categorical_column,dtype=tf.float32)
    feature_columns.append(num_list)

# %%
def make_dataset(data_df,label_df,epochs=10,shuffle=True,batch_size=32):
    dataset=tf.data.Dataset.from_tensor_slices((dict(data_df),label_df))
    if shuffle:
        dataset=dataset.shuffle(10000)
    dataset=dataset.repeat(epochs).batch(batch_size)
    return dataset

# %%
train_dataset=make_dataset(train_df,y_train,epochs=100)
eval_dataset=make_dataset(eval_df,y_eval,epochs=1,shuffle=False)

# %%
model=keras.models.Sequential()
model.add(keras.layers.DenseFeatures(feature_columns))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(2,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',
             optimizer=keras.optimizers.SGD(lr=0.01),
             metrics=['accuracy'])

# %%
history=model.fit(
    train_dataset,
    validation_data=eval_dataset,
    steps_per_epoch=20,
    validation_steps=8,
    epochs=100
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layer dense_features is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
#  1/20 [>.............................] - ETA: 0s - loss: 2.7881 - accuracy: 0.3750WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
# 20/20 [==============================] - 0s 23ms/step - loss: 2.3184 - accuracy: 0.6078 - val_loss: 0.6347 - val_accuracy: 0.6758
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6963 - accuracy: 0.6750 - val_loss: 0.6125 - val_accuracy: 0.6875
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6435 - accuracy: 0.6625 - val_loss: 0.6121 - val_accuracy: 0.7031
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6233 - accuracy: 0.6656 - val_loss: 0.6168 - val_accuracy: 0.6992
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6206 - accuracy: 0.6406 - val_loss: 0.6004 - val_accuracy: 0.6719
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6193 - accuracy: 0.6672 - val_loss: 0.5911 - val_accuracy: 0.6914
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5937 - accuracy: 0.6797 - val_loss: 0.5847 - val_accuracy: 0.7070
# Epoch 8/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6193 - accuracy: 0.6766 - val_loss: 0.5931 - val_accuracy: 0.6758
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6015 - accuracy: 0.6953 - val_loss: 0.5778 - val_accuracy: 0.6914
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6009 - accuracy: 0.6687 - val_loss: 0.5799 - val_accuracy: 0.6953
# Epoch 11/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5730 - accuracy: 0.7234 - val_loss: 0.5598 - val_accuracy: 0.6992
# Epoch 12/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5965 - accuracy: 0.6891 - val_loss: 0.5557 - val_accuracy: 0.7227
# Epoch 13/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5765 - accuracy: 0.6984 - val_loss: 0.5626 - val_accuracy: 0.6797
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.7156 - val_loss: 0.5573 - val_accuracy: 0.7031
# Epoch 15/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.6656 - val_loss: 0.5640 - val_accuracy: 0.6719
# Epoch 16/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5915 - accuracy: 0.6875 - val_loss: 0.5543 - val_accuracy: 0.7070
# Epoch 17/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5540 - accuracy: 0.7141 - val_loss: 0.5610 - val_accuracy: 0.7070
# Epoch 18/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5796 - accuracy: 0.7078 - val_loss: 0.5750 - val_accuracy: 0.6719
# Epoch 19/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5896 - accuracy: 0.6859 - val_loss: 0.6341 - val_accuracy: 0.6406
# Epoch 20/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5434 - accuracy: 0.7359 - val_loss: 0.5599 - val_accuracy: 0.7148
# Epoch 21/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.7234 - val_loss: 0.5485 - val_accuracy: 0.7031
# Epoch 22/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5765 - accuracy: 0.7078 - val_loss: 0.5535 - val_accuracy: 0.7227
# Epoch 23/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5626 - accuracy: 0.7156 - val_loss: 0.5559 - val_accuracy: 0.7344
# Epoch 24/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5380 - accuracy: 0.7250 - val_loss: 0.5599 - val_accuracy: 0.6875
# Epoch 25/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5765 - accuracy: 0.7266 - val_loss: 0.5669 - val_accuracy: 0.6719
# Epoch 26/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5471 - accuracy: 0.7172 - val_loss: 0.5384 - val_accuracy: 0.7266
# Epoch 27/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5809 - accuracy: 0.7188 - val_loss: 0.5406 - val_accuracy: 0.6992
# Epoch 28/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5504 - accuracy: 0.7391 - val_loss: 0.5533 - val_accuracy: 0.7344
# Epoch 29/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5511 - accuracy: 0.7297 - val_loss: 0.5314 - val_accuracy: 0.7227
# Epoch 30/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5569 - accuracy: 0.7266 - val_loss: 0.5695 - val_accuracy: 0.7148
# Epoch 31/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5788 - accuracy: 0.7109 - val_loss: 0.5301 - val_accuracy: 0.7148
# Epoch 32/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5358 - accuracy: 0.7469 - val_loss: 0.5405 - val_accuracy: 0.7070
# Epoch 33/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5522 - accuracy: 0.7234 - val_loss: 0.5593 - val_accuracy: 0.7305
# Epoch 34/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5661 - accuracy: 0.7281 - val_loss: 0.5534 - val_accuracy: 0.7344
# Epoch 35/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5603 - accuracy: 0.7344 - val_loss: 0.5270 - val_accuracy: 0.7031
# Epoch 36/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5310 - accuracy: 0.7500 - val_loss: 0.5916 - val_accuracy: 0.7266
# Epoch 37/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5820 - accuracy: 0.7234 - val_loss: 0.5244 - val_accuracy: 0.7383
# Epoch 38/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5365 - accuracy: 0.7344 - val_loss: 0.5536 - val_accuracy: 0.7383
# Epoch 39/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5308 - accuracy: 0.7516 - val_loss: 0.7641 - val_accuracy: 0.6055
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5487 - accuracy: 0.7500 - val_loss: 0.5386 - val_accuracy: 0.7305
# Epoch 41/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5578 - accuracy: 0.7375 - val_loss: 0.6799 - val_accuracy: 0.6523
# Epoch 42/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5549 - accuracy: 0.7219 - val_loss: 0.5466 - val_accuracy: 0.7266
# Epoch 43/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5322 - accuracy: 0.7422 - val_loss: 0.5878 - val_accuracy: 0.7188
# Epoch 44/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5172 - accuracy: 0.7547 - val_loss: 0.5572 - val_accuracy: 0.7227
# Epoch 45/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 0.7500 - val_loss: 0.6404 - val_accuracy: 0.6953
# Epoch 46/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5545 - accuracy: 0.7250 - val_loss: 0.5436 - val_accuracy: 0.7422
# Epoch 47/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5228 - accuracy: 0.7641 - val_loss: 0.5650 - val_accuracy: 0.7148
# Epoch 48/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5556 - accuracy: 0.7406 - val_loss: 0.5178 - val_accuracy: 0.7266
# Epoch 49/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5594 - accuracy: 0.7359 - val_loss: 0.5390 - val_accuracy: 0.7422
# Epoch 50/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5318 - accuracy: 0.7500 - val_loss: 0.5465 - val_accuracy: 0.6875
# Epoch 51/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5509 - accuracy: 0.7250 - val_loss: 0.5119 - val_accuracy: 0.7383
# Epoch 52/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5164 - accuracy: 0.7594 - val_loss: 0.5055 - val_accuracy: 0.7539
# Epoch 53/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5352 - accuracy: 0.7328 - val_loss: 0.5267 - val_accuracy: 0.7461
# Epoch 54/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5121 - accuracy: 0.7828 - val_loss: 0.5161 - val_accuracy: 0.7305
# Epoch 55/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5314 - accuracy: 0.7375 - val_loss: 0.5117 - val_accuracy: 0.7773
# Epoch 56/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5068 - accuracy: 0.7547 - val_loss: 0.5373 - val_accuracy: 0.7422
# Epoch 57/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5298 - accuracy: 0.7688 - val_loss: 0.5145 - val_accuracy: 0.7500
# Epoch 58/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5190 - accuracy: 0.7516 - val_loss: 0.5458 - val_accuracy: 0.6875
# Epoch 59/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5111 - accuracy: 0.7641 - val_loss: 0.5085 - val_accuracy: 0.7344
# Epoch 60/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5711 - accuracy: 0.7188 - val_loss: 0.5147 - val_accuracy: 0.7734
# Epoch 61/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4985 - accuracy: 0.7609 - val_loss: 0.5273 - val_accuracy: 0.7422
# Epoch 62/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5441 - accuracy: 0.7156 - val_loss: 0.5452 - val_accuracy: 0.7227
# Epoch 63/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5260 - accuracy: 0.7469 - val_loss: 0.5196 - val_accuracy: 0.7500
# Epoch 64/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5251 - accuracy: 0.7469 - val_loss: 0.5593 - val_accuracy: 0.7305
# Epoch 65/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5126 - accuracy: 0.7750 - val_loss: 0.5238 - val_accuracy: 0.7383
# Epoch 66/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5096 - accuracy: 0.7688 - val_loss: 0.5421 - val_accuracy: 0.7422
# Epoch 67/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5613 - accuracy: 0.7453 - val_loss: 0.5207 - val_accuracy: 0.7539
# Epoch 68/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5724 - accuracy: 0.7375 - val_loss: 0.5064 - val_accuracy: 0.7773
# Epoch 69/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4949 - accuracy: 0.7859 - val_loss: 0.5658 - val_accuracy: 0.7383
# Epoch 70/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5445 - accuracy: 0.7500 - val_loss: 0.5577 - val_accuracy: 0.6914
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5130 - accuracy: 0.7719 - val_loss: 0.5409 - val_accuracy: 0.7344
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5141 - accuracy: 0.7672 - val_loss: 0.5095 - val_accuracy: 0.7617
# Epoch 73/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5791 - accuracy: 0.7047 - val_loss: 0.5139 - val_accuracy: 0.7695
# Epoch 74/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4884 - accuracy: 0.7859 - val_loss: 0.5101 - val_accuracy: 0.7734
# Epoch 75/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.7797 - val_loss: 0.4938 - val_accuracy: 0.7656
# Epoch 76/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5046 - accuracy: 0.7641 - val_loss: 0.4926 - val_accuracy: 0.7539
# Epoch 77/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5396 - accuracy: 0.7375 - val_loss: 0.5685 - val_accuracy: 0.6719
# Epoch 78/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4869 - accuracy: 0.7953 - val_loss: 0.4974 - val_accuracy: 0.7656
# Epoch 79/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5271 - accuracy: 0.7484 - val_loss: 0.5091 - val_accuracy: 0.7695
# Epoch 80/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5199 - accuracy: 0.7531 - val_loss: 0.5023 - val_accuracy: 0.7812
# Epoch 81/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5194 - accuracy: 0.7781 - val_loss: 0.5244 - val_accuracy: 0.7539
# Epoch 82/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5293 - accuracy: 0.7516 - val_loss: 0.4938 - val_accuracy: 0.7578
# Epoch 83/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5136 - accuracy: 0.7688 - val_loss: 0.5274 - val_accuracy: 0.7422
# Epoch 84/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5113 - accuracy: 0.7812 - val_loss: 0.5320 - val_accuracy: 0.7383
# Epoch 85/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4958 - accuracy: 0.7812 - val_loss: 0.5434 - val_accuracy: 0.7539
# Epoch 86/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4897 - accuracy: 0.7875 - val_loss: 0.5020 - val_accuracy: 0.7617
# Epoch 87/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5380 - accuracy: 0.7547 - val_loss: 0.4979 - val_accuracy: 0.7695
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4906 - accuracy: 0.7969 - val_loss: 0.6179 - val_accuracy: 0.7188
# Epoch 89/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5063 - accuracy: 0.7609 - val_loss: 0.4901 - val_accuracy: 0.7539
# Epoch 90/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5372 - accuracy: 0.7672 - val_loss: 0.4956 - val_accuracy: 0.7578
# Epoch 91/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5032 - accuracy: 0.7703 - val_loss: 0.4893 - val_accuracy: 0.7539
# Epoch 92/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5117 - accuracy: 0.7703 - val_loss: 0.4874 - val_accuracy: 0.7656
# Epoch 93/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5108 - accuracy: 0.7578 - val_loss: 0.5096 - val_accuracy: 0.7461
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5231 - accuracy: 0.7578 - val_loss: 0.5200 - val_accuracy: 0.7383
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5135 - accuracy: 0.7688 - val_loss: 0.6917 - val_accuracy: 0.6523
# Epoch 96/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5413 - accuracy: 0.7453 - val_loss: 0.4912 - val_accuracy: 0.7812
# Epoch 97/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4792 - accuracy: 0.7828 - val_loss: 0.7108 - val_accuracy: 0.6523
# Epoch 98/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5277 - accuracy: 0.7661 - val_loss: 0.6758 - val_accuracy: 0.6602
# Epoch 99/100
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2000 batches). You may need to use the repeat() function when building your dataset.
#  0/20 [..............................] - 0s 0s/step - loss: 0.5277 - accuracy: 0.7661 - val_loss: 0.6758 - val_accuracy: 0.6602
