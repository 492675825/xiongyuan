# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import warnings
warnings.filterwarnings('ignore')
import time

# %%
train_file='./train.csv'
eval_file='./eval.csv'

# %%
train_df=pd.read_csv(train_file)
eval_df=pd.read_csv(eval_file)

# %%
y_train=train_df.pop('survived')
y_eval=eval_df.pop('survived')

# %%
categorical_columns=['sex','n_siblings_spouses','parch','class',
                     'deck','embark_town','alone']
numeric_columns=['age','fare']
feature_columns=[]

# %%
for categorical_column in categorical_columns:
    vocab=train_df[categorical_column].unique()
    vocab_list=tf.feature_column.categorical_column_with_vocabulary_list(
        categorical_column,vocab)
    vocab_list=tf.feature_column.indicator_column(vocab_list)
    feature_columns.append(vocab_list)

# %%
for categorical_column in numeric_columns:
    num_list=tf.feature_column.numeric_column(categorical_column,dtype=tf.float64)
    feature_columns.append(num_list)

# %%
def make_dataset(train_df,label_df,epochs=10,shuffle=True,batch_size=32):
    dataset=tf.data.Dataset.from_tensor_slices((dict(train_df),label_df))
    if shuffle:
        dataset=dataset.shuffle(10000)
    dataset=dataset.repeat(epochs).batch(batch_size)
    return dataset

# %%
model=keras.models.Sequential()
model.add(keras.layers.DenseFeatures(feature_columns))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(2,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',
             optimizer=keras.optimizers.SGD(lr=0.01),
             metrics=['accuracy'])

# %%
train_dataset=make_dataset(train_df,y_train,epochs=100)
eval_dataset=make_dataset(eval_df,y_eval,shuffle=False,epochs=1)

# %%
model.fit(
    train_dataset,
    validation_data=eval_dataset,
    steps_per_epoch=18,
    validation_steps=8,
    epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layer dense_features is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
#  1/18 [>.............................] - ETA: 0s - loss: 1.7836 - accuracy: 0.5625WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
# 18/18 [==============================] - 0s 16ms/step - loss: 1.6312 - accuracy: 0.6024 - val_loss: 0.8699 - val_accuracy: 0.6367
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9185 - accuracy: 0.6285 - val_loss: 0.6338 - val_accuracy: 0.6445
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7539 - accuracy: 0.6372 - val_loss: 0.6450 - val_accuracy: 0.6641
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6271 - accuracy: 0.6719 - val_loss: 0.6699 - val_accuracy: 0.6367
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6157 - accuracy: 0.6736 - val_loss: 0.5858 - val_accuracy: 0.7070
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6561 - accuracy: 0.6389 - val_loss: 0.6210 - val_accuracy: 0.6406
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5782 - accuracy: 0.7031 - val_loss: 0.6174 - val_accuracy: 0.6562
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6111 - accuracy: 0.6719 - val_loss: 0.5866 - val_accuracy: 0.7031
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5818 - accuracy: 0.7118 - val_loss: 0.5866 - val_accuracy: 0.7188
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6228 - accuracy: 0.6562 - val_loss: 0.5913 - val_accuracy: 0.7031
# Epoch 11/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.6875 - val_loss: 0.5993 - val_accuracy: 0.6719
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5965 - accuracy: 0.6840 - val_loss: 0.5798 - val_accuracy: 0.7070
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5891 - accuracy: 0.6910 - val_loss: 0.5862 - val_accuracy: 0.7031
# Epoch 14/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5939 - accuracy: 0.6840 - val_loss: 0.5799 - val_accuracy: 0.7109
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6025 - accuracy: 0.6736 - val_loss: 0.5715 - val_accuracy: 0.7109
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5626 - accuracy: 0.6979 - val_loss: 0.5762 - val_accuracy: 0.6953
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.6997 - val_loss: 0.6092 - val_accuracy: 0.6914
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5861 - accuracy: 0.6823 - val_loss: 0.6075 - val_accuracy: 0.7031
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.7049 - val_loss: 0.5682 - val_accuracy: 0.7031
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.6753 - val_loss: 0.5885 - val_accuracy: 0.7031
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5866 - accuracy: 0.7049 - val_loss: 0.5719 - val_accuracy: 0.7188
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5664 - accuracy: 0.7222 - val_loss: 0.5600 - val_accuracy: 0.7031
# Epoch 23/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5705 - accuracy: 0.6944 - val_loss: 0.5743 - val_accuracy: 0.6953
# Epoch 24/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5757 - accuracy: 0.7049 - val_loss: 0.5660 - val_accuracy: 0.6992
# Epoch 25/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5646 - accuracy: 0.7083 - val_loss: 0.6010 - val_accuracy: 0.6914
# Epoch 26/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5727 - accuracy: 0.7188 - val_loss: 0.5568 - val_accuracy: 0.7148
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5719 - accuracy: 0.6979 - val_loss: 0.5990 - val_accuracy: 0.6992
# Epoch 28/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5552 - accuracy: 0.7118 - val_loss: 0.5541 - val_accuracy: 0.7109
# Epoch 29/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5767 - accuracy: 0.6962 - val_loss: 0.5639 - val_accuracy: 0.7227
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.6858 - val_loss: 0.5482 - val_accuracy: 0.7031
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5602 - accuracy: 0.7031 - val_loss: 0.5494 - val_accuracy: 0.7109
# Epoch 32/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.7344 - val_loss: 0.5593 - val_accuracy: 0.7031
# Epoch 33/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5648 - accuracy: 0.6962 - val_loss: 0.5457 - val_accuracy: 0.7031
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5603 - accuracy: 0.7188 - val_loss: 0.5738 - val_accuracy: 0.6914
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5312 - accuracy: 0.7188 - val_loss: 0.5909 - val_accuracy: 0.6953
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5537 - accuracy: 0.7326 - val_loss: 0.5586 - val_accuracy: 0.6992
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5510 - accuracy: 0.7188 - val_loss: 0.6686 - val_accuracy: 0.6211
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5940 - accuracy: 0.6910 - val_loss: 0.5868 - val_accuracy: 0.7031
# Epoch 39/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.7031 - val_loss: 0.5489 - val_accuracy: 0.7109
# Epoch 40/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5416 - accuracy: 0.7066 - val_loss: 0.5433 - val_accuracy: 0.7305
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5845 - accuracy: 0.6736 - val_loss: 0.5520 - val_accuracy: 0.7031
# Epoch 42/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5710 - accuracy: 0.7292 - val_loss: 0.5463 - val_accuracy: 0.7227
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5408 - accuracy: 0.7222 - val_loss: 0.5833 - val_accuracy: 0.7227
# Epoch 44/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.7170 - val_loss: 0.5562 - val_accuracy: 0.7383
# Epoch 45/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5648 - accuracy: 0.7205 - val_loss: 0.5450 - val_accuracy: 0.7500
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5673 - accuracy: 0.7396 - val_loss: 0.5378 - val_accuracy: 0.7461
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5582 - accuracy: 0.7101 - val_loss: 0.6707 - val_accuracy: 0.6328
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5743 - accuracy: 0.7031 - val_loss: 0.6080 - val_accuracy: 0.6914
# Epoch 49/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5622 - accuracy: 0.7188 - val_loss: 0.5385 - val_accuracy: 0.7461
# Epoch 50/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5294 - accuracy: 0.7344 - val_loss: 0.5339 - val_accuracy: 0.7070
# Epoch 51/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5339 - accuracy: 0.7483 - val_loss: 0.5415 - val_accuracy: 0.7578
# Epoch 52/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6181 - accuracy: 0.6892 - val_loss: 0.5281 - val_accuracy: 0.7266
# Epoch 53/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.7431 - val_loss: 0.5404 - val_accuracy: 0.7383
# Epoch 54/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.6944 - val_loss: 0.5361 - val_accuracy: 0.7344
# Epoch 55/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5510 - accuracy: 0.7188 - val_loss: 0.5279 - val_accuracy: 0.7656
# Epoch 56/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5253 - accuracy: 0.7274 - val_loss: 0.5366 - val_accuracy: 0.7070
# Epoch 57/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5536 - accuracy: 0.7205 - val_loss: 0.5350 - val_accuracy: 0.7109
# Epoch 58/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5594 - accuracy: 0.7205 - val_loss: 0.5229 - val_accuracy: 0.7266
# Epoch 59/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5411 - accuracy: 0.7188 - val_loss: 0.5243 - val_accuracy: 0.7461
# Epoch 60/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5289 - accuracy: 0.7639 - val_loss: 0.5437 - val_accuracy: 0.7500
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.7465 - val_loss: 0.5213 - val_accuracy: 0.7422
# Epoch 62/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5567 - accuracy: 0.7326 - val_loss: 0.5196 - val_accuracy: 0.7500
# Epoch 63/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.7431 - val_loss: 0.5924 - val_accuracy: 0.7188
# Epoch 64/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5176 - accuracy: 0.7413 - val_loss: 0.5372 - val_accuracy: 0.7383
# Epoch 65/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5523 - accuracy: 0.7170 - val_loss: 0.5343 - val_accuracy: 0.7344
# Epoch 66/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5917 - accuracy: 0.7135 - val_loss: 0.5183 - val_accuracy: 0.7617
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5286 - accuracy: 0.7465 - val_loss: 0.5206 - val_accuracy: 0.7305
# Epoch 68/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5298 - accuracy: 0.7361 - val_loss: 0.5274 - val_accuracy: 0.7422
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5103 - accuracy: 0.7517 - val_loss: 0.5273 - val_accuracy: 0.7305
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5316 - accuracy: 0.7535 - val_loss: 0.5316 - val_accuracy: 0.7266
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5673 - accuracy: 0.6997 - val_loss: 0.5182 - val_accuracy: 0.7422
# Epoch 72/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5635 - accuracy: 0.7257 - val_loss: 0.5103 - val_accuracy: 0.7461
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7153 - val_loss: 0.5328 - val_accuracy: 0.7461
# Epoch 74/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5234 - accuracy: 0.7413 - val_loss: 0.5630 - val_accuracy: 0.7188
# Epoch 75/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5211 - accuracy: 0.7500 - val_loss: 0.5094 - val_accuracy: 0.7539
# Epoch 76/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5494 - accuracy: 0.7396 - val_loss: 0.5102 - val_accuracy: 0.7773
# Epoch 77/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5236 - accuracy: 0.7691 - val_loss: 0.6141 - val_accuracy: 0.6328
# Epoch 78/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5225 - accuracy: 0.7257 - val_loss: 0.5736 - val_accuracy: 0.7188
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.7396 - val_loss: 0.6248 - val_accuracy: 0.6836
# Epoch 80/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5506 - accuracy: 0.7396 - val_loss: 0.6090 - val_accuracy: 0.7266
# Epoch 81/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.7587 - val_loss: 0.5777 - val_accuracy: 0.7227
# Epoch 82/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4981 - accuracy: 0.7674 - val_loss: 0.5168 - val_accuracy: 0.7422
# Epoch 83/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7795 - val_loss: 0.5091 - val_accuracy: 0.7344
# Epoch 84/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.7465 - val_loss: 0.5577 - val_accuracy: 0.7109
# Epoch 85/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7361 - val_loss: 0.5287 - val_accuracy: 0.7227
# Epoch 86/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5368 - accuracy: 0.7604 - val_loss: 0.5147 - val_accuracy: 0.7578
# Epoch 87/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5172 - accuracy: 0.7639 - val_loss: 0.5119 - val_accuracy: 0.7266
# Epoch 88/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.7431 - val_loss: 0.5142 - val_accuracy: 0.7461
# Epoch 89/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5119 - accuracy: 0.7552 - val_loss: 0.5137 - val_accuracy: 0.7383
# Epoch 90/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5257 - accuracy: 0.7431 - val_loss: 0.6554 - val_accuracy: 0.6602
# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5459 - accuracy: 0.7413 - val_loss: 0.5166 - val_accuracy: 0.7266
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5118 - accuracy: 0.7656 - val_loss: 0.5616 - val_accuracy: 0.7031
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4862 - accuracy: 0.7812 - val_loss: 0.5039 - val_accuracy: 0.7539
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5737 - accuracy: 0.7153 - val_loss: 0.5160 - val_accuracy: 0.7695
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7535 - val_loss: 0.5207 - val_accuracy: 0.7578
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5003 - accuracy: 0.7760 - val_loss: 0.4950 - val_accuracy: 0.7539
# Epoch 97/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5397 - accuracy: 0.7309 - val_loss: 0.5062 - val_accuracy: 0.7500
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5130 - accuracy: 0.7708 - val_loss: 0.5008 - val_accuracy: 0.7617
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.7535 - val_loss: 0.5983 - val_accuracy: 0.7070
# Epoch 100/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.7847 - val_loss: 0.5731 - val_accuracy: 0.7383
