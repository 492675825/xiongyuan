# %%
import pandas as pd
import numpy as np 
import os
import time
import tensorflow as tf
from tensorflow import keras
import warnings
warnings.filterwarnings('ignore')
print(tf.__version__)
# Out:
# 2.3.1

# %%
train_file='./train.csv'
eval_file='./eval.csv'

# %%
train_df=pd.read_csv(train_file)
eval_df=pd.read_csv(eval_file)

# %%
y_train=train_df.pop('survived')
y_eval=eval_df.pop('survived')

# %%
categorical_columns=['sex','n_siblings_spouses','parch','class',
                     'deck','embark_town','alone']
numeric_columns=['age','fare']
feature_columns=[]

# %%
for categorical_column in categorical_columns:
    vocab=train_df[categorical_column].unique()
    print(categorical_column,vocab)
    vocab_list=tf.feature_column.categorical_column_with_vocabulary_list(
        categorical_column,vocab)
    vocab_list=tf.feature_column.indicator_column(vocab_list)
    feature_columns.append(vocab_list)
# Out:
# sex ['male' 'female']
# n_siblings_spouses [1 0 3 4 2 5 8]
# parch [0 1 2 5 3 4]
# class ['Third' 'First' 'Second']
# deck ['unknown' 'C' 'G' 'A' 'B' 'D' 'F' 'E']
# embark_town ['Southampton' 'Cherbourg' 'Queenstown' 'unknown']
# alone ['n' 'y']

# %%
for categorical_column in numeric_columns:
    num_list=tf.feature_column.numeric_column(categorical_column,dtype=tf.float32)
    feature_columns.append(num_list)

# %%
def make_dataset(data_df,label_df,epochs=10,shuffle=True,batch_size=32):
    dataset=tf.data.Dataset.from_tensor_slices((dict(data_df),label_df))
    if shuffle:
        dataset=dataset.shuffle(10000)
    dataset=dataset.repeat(epochs).batch(batch_size)
    return dataset

# %%
train_dataset=make_dataset(train_df,y_train,epochs=100)
eval_dataset=make_dataset(eval_df,y_eval,epochs=1,shuffle=False)

# %%
model=keras.models.Sequential()
model.add(keras.layers.DenseFeatures(feature_columns))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(100,activation='relu'))
model.add(keras.layers.Dense(2,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',
                optimizer=keras.optimizers.SGD(lr=0.01),
             metrics=['accuracy'])

# %%
history=model.fit(
    train_dataset,
    validation_data=eval_dataset,
    steps_per_epoch=20,
    validation_steps=8,
    epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layer dense_features_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
#  1/20 [>.............................] - ETA: 0s - loss: 1.4840 - accuracy: 0.4062WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'dict'> input: {'sex': <tf.Tensor 'ExpandDims_8:0' shape=(None, 1) dtype=string>, 'age': <tf.Tensor 'ExpandDims:0' shape=(None, 1) dtype=float64>, 'n_siblings_spouses': <tf.Tensor 'ExpandDims_6:0' shape=(None, 1) dtype=int64>, 'parch': <tf.Tensor 'ExpandDims_7:0' shape=(None, 1) dtype=int64>, 'fare': <tf.Tensor 'ExpandDims_5:0' shape=(None, 1) dtype=float64>, 'class': <tf.Tensor 'ExpandDims_2:0' shape=(None, 1) dtype=string>, 'deck': <tf.Tensor 'ExpandDims_3:0' shape=(None, 1) dtype=string>, 'embark_town': <tf.Tensor 'ExpandDims_4:0' shape=(None, 1) dtype=string>, 'alone': <tf.Tensor 'ExpandDims_1:0' shape=(None, 1) dtype=string>}
# Consider rewriting this model with the Functional API.
# 20/20 [==============================] - 0s 21ms/step - loss: 1.5527 - accuracy: 0.6359 - val_loss: 0.6227 - val_accuracy: 0.6875
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7057 - accuracy: 0.6516 - val_loss: 0.6148 - val_accuracy: 0.6797
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.6687 - val_loss: 0.6035 - val_accuracy: 0.6953
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6303 - accuracy: 0.6703 - val_loss: 0.6002 - val_accuracy: 0.6875
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6531 - accuracy: 0.6594 - val_loss: 0.5955 - val_accuracy: 0.6875
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6016 - accuracy: 0.6672 - val_loss: 0.6173 - val_accuracy: 0.6484
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6010 - accuracy: 0.6703 - val_loss: 0.6165 - val_accuracy: 0.7031
# Epoch 8/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6433 - accuracy: 0.6453 - val_loss: 0.6005 - val_accuracy: 0.6758
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5833 - accuracy: 0.7031 - val_loss: 0.5823 - val_accuracy: 0.6914
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5883 - accuracy: 0.6938 - val_loss: 0.5958 - val_accuracy: 0.6836
# Epoch 11/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6065 - accuracy: 0.6812 - val_loss: 0.5837 - val_accuracy: 0.7031
# Epoch 12/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6027 - accuracy: 0.6719 - val_loss: 0.6011 - val_accuracy: 0.7188
# Epoch 13/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5956 - accuracy: 0.6969 - val_loss: 0.5778 - val_accuracy: 0.6992
# Epoch 14/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5990 - accuracy: 0.6844 - val_loss: 0.5801 - val_accuracy: 0.6875
# Epoch 15/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5877 - accuracy: 0.6969 - val_loss: 0.5901 - val_accuracy: 0.6953
# Epoch 16/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5648 - accuracy: 0.7063 - val_loss: 0.5751 - val_accuracy: 0.7031
# Epoch 17/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6085 - accuracy: 0.6797 - val_loss: 0.6121 - val_accuracy: 0.7109
# Epoch 18/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5852 - accuracy: 0.6875 - val_loss: 0.5847 - val_accuracy: 0.6836
# Epoch 19/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5826 - accuracy: 0.7047 - val_loss: 0.5800 - val_accuracy: 0.7031
# Epoch 20/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5930 - accuracy: 0.7016 - val_loss: 0.5707 - val_accuracy: 0.6992
# Epoch 21/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5525 - accuracy: 0.7094 - val_loss: 0.5755 - val_accuracy: 0.7070
# Epoch 22/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5901 - accuracy: 0.6750 - val_loss: 0.5718 - val_accuracy: 0.7109
# Epoch 23/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5854 - accuracy: 0.6812 - val_loss: 0.6719 - val_accuracy: 0.6094
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5776 - accuracy: 0.6984 - val_loss: 0.5805 - val_accuracy: 0.6641
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5878 - accuracy: 0.6953 - val_loss: 0.5598 - val_accuracy: 0.7070
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5399 - accuracy: 0.7219 - val_loss: 0.6054 - val_accuracy: 0.6602
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5945 - accuracy: 0.6859 - val_loss: 0.5594 - val_accuracy: 0.6953
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.6797 - val_loss: 0.5789 - val_accuracy: 0.7070
# Epoch 29/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5846 - accuracy: 0.7031 - val_loss: 0.5636 - val_accuracy: 0.7070
# Epoch 30/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5428 - accuracy: 0.7312 - val_loss: 0.5516 - val_accuracy: 0.7070
# Epoch 31/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6023 - accuracy: 0.6781 - val_loss: 0.5423 - val_accuracy: 0.7188
# Epoch 32/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5387 - accuracy: 0.7344 - val_loss: 0.5626 - val_accuracy: 0.7109
# Epoch 33/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5418 - accuracy: 0.7312 - val_loss: 0.5365 - val_accuracy: 0.7031
# Epoch 34/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5706 - accuracy: 0.6969 - val_loss: 0.5552 - val_accuracy: 0.6992
# Epoch 35/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5862 - accuracy: 0.6922 - val_loss: 0.5975 - val_accuracy: 0.6953
# Epoch 36/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5504 - accuracy: 0.7266 - val_loss: 0.5460 - val_accuracy: 0.7031
# Epoch 37/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5748 - accuracy: 0.6891 - val_loss: 0.5427 - val_accuracy: 0.7109
# Epoch 38/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5669 - accuracy: 0.7219 - val_loss: 0.5433 - val_accuracy: 0.7266
# Epoch 39/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5581 - accuracy: 0.7250 - val_loss: 0.5556 - val_accuracy: 0.7305
# Epoch 40/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5358 - accuracy: 0.7250 - val_loss: 0.5344 - val_accuracy: 0.7031
# Epoch 41/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5445 - accuracy: 0.7266 - val_loss: 0.5382 - val_accuracy: 0.7188
# Epoch 42/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5790 - accuracy: 0.7125 - val_loss: 0.5306 - val_accuracy: 0.7148
# Epoch 43/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5459 - accuracy: 0.7219 - val_loss: 0.5257 - val_accuracy: 0.7383
# Epoch 44/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5765 - accuracy: 0.6969 - val_loss: 0.5452 - val_accuracy: 0.7227
# Epoch 45/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.7328 - val_loss: 0.5350 - val_accuracy: 0.7539
# Epoch 46/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5582 - accuracy: 0.7203 - val_loss: 0.5333 - val_accuracy: 0.7070
# Epoch 47/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5721 - accuracy: 0.6922 - val_loss: 0.5299 - val_accuracy: 0.7188
# Epoch 48/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5384 - accuracy: 0.7328 - val_loss: 0.5231 - val_accuracy: 0.7227
# Epoch 49/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5310 - accuracy: 0.7375 - val_loss: 0.6356 - val_accuracy: 0.6523
# Epoch 50/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5516 - accuracy: 0.7156 - val_loss: 0.5310 - val_accuracy: 0.7266
# Epoch 51/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5424 - accuracy: 0.7109 - val_loss: 0.5383 - val_accuracy: 0.7031
# Epoch 52/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5408 - accuracy: 0.7266 - val_loss: 0.5239 - val_accuracy: 0.7461
# Epoch 53/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5453 - accuracy: 0.7312 - val_loss: 0.5227 - val_accuracy: 0.7227
# Epoch 54/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5363 - accuracy: 0.7188 - val_loss: 0.5277 - val_accuracy: 0.7266
# Epoch 55/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5490 - accuracy: 0.7422 - val_loss: 0.5686 - val_accuracy: 0.7109
# Epoch 56/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5395 - accuracy: 0.7266 - val_loss: 0.5860 - val_accuracy: 0.7109
# Epoch 57/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5219 - accuracy: 0.7375 - val_loss: 0.5261 - val_accuracy: 0.7266
# Epoch 58/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5758 - accuracy: 0.7125 - val_loss: 0.5659 - val_accuracy: 0.7148
# Epoch 59/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5376 - accuracy: 0.7453 - val_loss: 0.5189 - val_accuracy: 0.7539
# Epoch 60/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5272 - accuracy: 0.7516 - val_loss: 0.5262 - val_accuracy: 0.7422
# Epoch 61/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.7125 - val_loss: 0.5285 - val_accuracy: 0.7031
# Epoch 62/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5366 - accuracy: 0.7297 - val_loss: 0.5118 - val_accuracy: 0.7422
# Epoch 63/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5149 - accuracy: 0.7500 - val_loss: 0.6143 - val_accuracy: 0.6367
# Epoch 64/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5277 - accuracy: 0.7219 - val_loss: 0.5164 - val_accuracy: 0.7383
# Epoch 65/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5838 - accuracy: 0.7078 - val_loss: 0.5475 - val_accuracy: 0.7422
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5603 - accuracy: 0.7141 - val_loss: 0.6980 - val_accuracy: 0.6094
# Epoch 67/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5573 - accuracy: 0.7172 - val_loss: 0.5825 - val_accuracy: 0.7109
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5100 - accuracy: 0.7641 - val_loss: 0.5951 - val_accuracy: 0.7109
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5413 - accuracy: 0.7312 - val_loss: 0.5427 - val_accuracy: 0.6914
# Epoch 70/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.7516 - val_loss: 0.5097 - val_accuracy: 0.7617
# Epoch 71/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5671 - accuracy: 0.7016 - val_loss: 0.5479 - val_accuracy: 0.7266
# Epoch 72/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.7359 - val_loss: 0.7335 - val_accuracy: 0.5664
# Epoch 73/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5305 - accuracy: 0.7344 - val_loss: 0.6248 - val_accuracy: 0.7109
# Epoch 74/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5256 - accuracy: 0.7500 - val_loss: 0.5669 - val_accuracy: 0.6484
# Epoch 75/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5164 - accuracy: 0.7484 - val_loss: 0.5625 - val_accuracy: 0.7188
# Epoch 76/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.7250 - val_loss: 0.5471 - val_accuracy: 0.7227
# Epoch 77/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5389 - accuracy: 0.7219 - val_loss: 0.5076 - val_accuracy: 0.7539
# Epoch 78/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5092 - accuracy: 0.7578 - val_loss: 0.5212 - val_accuracy: 0.7383
# Epoch 79/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5479 - accuracy: 0.7359 - val_loss: 0.5175 - val_accuracy: 0.7422
# Epoch 80/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5007 - accuracy: 0.7516 - val_loss: 0.5432 - val_accuracy: 0.7266
# Epoch 81/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5068 - accuracy: 0.7719 - val_loss: 0.5113 - val_accuracy: 0.7656
# Epoch 82/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5112 - accuracy: 0.7531 - val_loss: 0.5048 - val_accuracy: 0.7578
# Epoch 83/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5412 - accuracy: 0.7344 - val_loss: 0.5424 - val_accuracy: 0.7148
# Epoch 84/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5065 - accuracy: 0.7656 - val_loss: 0.5063 - val_accuracy: 0.7500
# Epoch 85/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5042 - accuracy: 0.7656 - val_loss: 0.4941 - val_accuracy: 0.7773
# Epoch 86/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5405 - accuracy: 0.7391 - val_loss: 0.5115 - val_accuracy: 0.7500
# Epoch 87/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5340 - accuracy: 0.7391 - val_loss: 0.5085 - val_accuracy: 0.7578
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5291 - accuracy: 0.7391 - val_loss: 0.5056 - val_accuracy: 0.7422
# Epoch 89/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5118 - accuracy: 0.7656 - val_loss: 0.4926 - val_accuracy: 0.7539
# Epoch 90/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5045 - accuracy: 0.7641 - val_loss: 0.5100 - val_accuracy: 0.7617
# Epoch 91/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5289 - accuracy: 0.7578 - val_loss: 0.5016 - val_accuracy: 0.7383
# Epoch 92/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5354 - accuracy: 0.7469 - val_loss: 0.4999 - val_accuracy: 0.7461
# Epoch 93/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5232 - accuracy: 0.7563 - val_loss: 0.5869 - val_accuracy: 0.7148
# Epoch 94/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5254 - accuracy: 0.7563 - val_loss: 0.5462 - val_accuracy: 0.7109
# Epoch 95/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5157 - accuracy: 0.7563 - val_loss: 0.5101 - val_accuracy: 0.7539
# Epoch 96/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5269 - accuracy: 0.7437 - val_loss: 0.5243 - val_accuracy: 0.7148
# Epoch 97/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5428 - accuracy: 0.7406 - val_loss: 0.5129 - val_accuracy: 0.7422
# Epoch 98/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5407 - accuracy: 0.7452 - val_loss: 0.4958 - val_accuracy: 0.7539
# Epoch 99/100
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2000 batches). You may need to use the repeat() function when building your dataset.
#  0/20 [..............................] - 0s 0s/step - loss: 0.5407 - accuracy: 0.7452 - val_loss: 0.4958 - val_accuracy: 0.7539
